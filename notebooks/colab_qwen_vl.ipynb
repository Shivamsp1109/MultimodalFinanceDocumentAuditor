# %% [markdown]
# # Qwen-VL + PaddleOCR (Colab)
# This notebook runs the pipeline on GPU (T4).

# %%
# !pip -q install -r requirements.txt
# !pip -q install -r requirements-ml.txt

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

# %%
# Example run (replace with your invoice image path)
# !python -m src.main --input data/sample_invoice.png --model_name Qwen/Qwen2-VL-2B-Instruct
